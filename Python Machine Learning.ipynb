# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

food_df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv',encoding = 'latin-1')
food_df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
correlation_df = food_df[['Y2014','Y2015','Y2016','Y2017','Y2018','Element Code']]
sns.heatmap(data=correlation_df)
plt.show()

# %%
food_df['Y2014'].isnull().sum()
# Out:
# 1479

# %%
food_df.groupby("Element")['Y2017'].sum()
# Out:
# Element
# Domestic supply quantity                  1883317.47
# Export Quantity                            172223.86
# Fat supply quantity (g/capita/day)           9042.66
# Feed                                       212295.28
# Food                                      1122060.05
# Food supply (kcal/capita/day)              407862.00
# Food supply quantity (kg/capita/yr)         43645.14
# Import Quantity                            272626.56
# Losses                                     148367.00
# Other uses (non-food)                       88890.94
# Processing                                 251973.00
# Production                                1829977.82
# Protein supply quantity (g/capita/day)      10581.39
# Residuals                                   37161.00
# Seed                                        22424.14
# Stock Variation                             47318.91
# Total Population - Both sexes              974290.00
# Tourist consumption                            91.00
# ...

# %%
food_df['Area'].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "Côte d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo'], dtype=object)

# %%
sel = food_df[['Y2017','Area']]
selg = sel.groupby('Area')['Y2017'].sum()
selg.sort_values()
# Out:
# Area
# Sudan (former)                    0.00
# Ethiopia PDR                      0.00
# Comoros                          59.84
# Seychelles                      442.34
# Sao Tome and Principe         12662.63
# Cabo Verde                    14650.74
# Guinea-Bissau                 19102.77
# Lesotho                       21267.96
# Botswana                      22101.30
# Djibouti                      22729.91
# Gambia                        23154.18
# Gabon                         27979.64
# Liberia                       29342.20
# Namibia                       29874.89
# Central African Republic      29937.00
# Congo                         41181.68
# Togo                          48138.45
# Mauritius                     51114.83
# Eswatini                      54343.33
# Sierra Leone                  55311.33
# Chad                          71594.68
# Rwanda                        73663.69
# Senegal                       95681.15
# Guinea                        98138.87
# ...

# %%
food_df.groupby('Item').sum()
# Out:
#                      Area Code  \
# Item
# Alcohol, Non-Food        31219
# Alcoholic Beverages      61213
# Animal Products          14775
# Animal fats              69295
# Apples and products      55916
# ...                        ...
# Vegetables, Other        63492
# Vegetal Products         14775
# Wheat and products       70393
# Wine                     53932
# Yams                     45833
#
#                                                                   Area  \
# Item
# Alcohol, Non-Food    AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAngo...
# Alcoholic Beverages  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Animal Products      AlgeriaAlgeriaAlgeriaAngolaAngolaAngolaBeninBe...
# Animal fats          AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Apples and products  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# ...                                                                ...
# ...

# %%
food_df.groupby("Area")['Y2017'].sum().sort_values()
# Out:
# Area
# Sudan (former)                    0.00
# Ethiopia PDR                      0.00
# Comoros                          59.84
# Seychelles                      442.34
# Sao Tome and Principe         12662.63
# Cabo Verde                    14650.74
# Guinea-Bissau                 19102.77
# Lesotho                       21267.96
# Botswana                      22101.30
# Djibouti                      22729.91
# Gambia                        23154.18
# Gabon                         27979.64
# Liberia                       29342.20
# Namibia                       29874.89
# Central African Republic      29937.00
# Congo                         41181.68
# Togo                          48138.45
# Mauritius                     51114.83
# Eswatini                      54343.33
# Sierra Leone                  55311.33
# Chad                          71594.68
# Rwanda                        73663.69
# Senegal                       95681.15
# Guinea                        98138.87
# ...
